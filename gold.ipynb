# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Gold price dataset 2024.csv")

# %%
df
# Out:
#           Date    USD_INR   Goldrate
# 0   2024-01-01  83.240601  ₹5,066.31
# 1   2024-01-08  83.076103  ₹4,966.31
# 2   2024-01-15  83.160599  ₹5,015.33
# 3   2024-01-22  83.146103  ₹4,950.84
# 4   2024-01-29  82.927597  ₹4,976.77
# 5   2024-02-05  82.985298  ₹4,953.90
# 6   2024-02-12  83.009598  ₹4,938.73
# 7   2024-02-19  82.872299  ₹4,934.99
# 8   2024-02-26  82.910400  ₹4,960.54
# 9   2024-03-04  82.752296  ₹5,167.64
# 10  2024-03-11  82.965599  ₹5,326.46
# 11  2024-03-18  83.226601  ₹5,283.44
# 12  2024-03-25  83.392998  ₹5,341.21
# 13  2024-04-01  83.477798  ₹5,543.85
# 14  2024-04-08  83.349297  ₹5,737.21
# 15  2024-04-15  83.544998  ₹5,874.86
# 16  2024-04-22  83.301804  ₹5,720.10
# 17  2024-04-29  83.406303  ₹5,744.34
# 18  2024-05-06  83.459396  ₹5,724.77
# 19  2024-05-13  83.470100  ₹5,754.39
# 20  2024-05-20  83.286400  ₹5,966.34
# 21  2024-05-27  83.320900  ₹5,765.04
# 22  2024-06-03  83.473099  ₹5,757.16
# 23  2024-06-10  83.522102  ₹5,691.70
# ...

# %%
df['Goldrate']=df['Goldrate'].replace('₹','',regex=True).replace(',','',regex=True).astype(float)

# %%
df['Goldrate']
# Out:
# 0     5066.31
# 1     4966.31
# 2     5015.33
# 3     4950.84
# 4     4976.77
# 5     4953.90
# 6     4938.73
# 7     4934.99
# 8     4960.54
# 9     5167.64
# 10    5326.46
# 11    5283.44
# 12    5341.21
# 13    5543.85
# 14    5737.21
# 15    5874.86
# 16    5720.10
# 17    5744.34
# 18    5724.77
# 19    5754.39
# 20    5966.34
# 21    5765.04
# 22    5757.16
# 23    5691.70
# 24    5710.88
# 25    5738.99
# 26    5734.29
# 27    5803.07
# 28    5964.96
# 29    5909.38
# 30    5883.33
# 31    5967.66
# 32    6114.39
# 33    6182.13
# 34    6222.57
# 35    6179.61
# 36    6201.84
# 37    6384.57
# 38    6548.44
# 39    6507.66
# 40    6544.00
# 41    6563.33
# 42    6741.68
# 43    6795.35
# 44    6786.87
# 45    6523.10
# 46    6498.43
# 47    6524.06
# 48    6593.10
# 49    6654.03
# 50    6639.21
# 51    6560.64
# 52    6585.39
# Name: Goldrate, dtype: float64

# %%
sns.regplot(x='USD_INR',y='Goldrate',data=df)
# Out:
# <Axes: xlabel='USD_INR', ylabel='Goldrate'>

# %%
sns.boxplot(df['USD_INR'])
# Out:
# <Axes: ylabel='USD_INR'>

# %%
sns.boxplot(df['Goldrate'])
# Out:
# <Axes: ylabel='Goldrate'>

# %%
X=df['USD_INR']
y=df['Goldrate']

# %%
X
# Out:
# 0     83.240601
# 1     83.076103
# 2     83.160599
# 3     83.146103
# 4     82.927597
# 5     82.985298
# 6     83.009598
# 7     82.872299
# 8     82.910400
# 9     82.752296
# 10    82.965599
# 11    83.226601
# 12    83.392998
# 13    83.477798
# 14    83.349297
# 15    83.544998
# 16    83.301804
# 17    83.406303
# 18    83.459396
# 19    83.470100
# 20    83.286400
# 21    83.320900
# 22    83.473099
# 23    83.522102
# 24    83.601601
# 25    83.450897
# 26    83.493401
# 27    83.518501
# 28    83.674301
# 29    83.744400
# 30    83.743896
# 31    83.988998
# 32    83.948303
# 33    83.940598
# 34    83.895103
# 35    83.983597
# 36    83.934799
# 37    83.614700
# 38    83.617104
# 39    84.009399
# 40    83.945999
# 41    84.053802
# 42    84.081802
# 43    84.091499
# 44    84.306396
# 45    84.473801
# 46    84.488297
# 47    84.556999
# 48    84.666000
# 49    84.802002
# 50    84.945000
# 51    85.386002
# 52    85.786598
# Name: USD_INR, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((47,), (6,))

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_scaled=sc.fit_transform(X_train.values.reshape(-1,1))
X_test_scaled=sc.transform(X_test.values.reshape(-1,1))

# %%
X_train_scaled
# Out:
# array([[-0.4753469 ],
#        [ 1.91603897],
#        [-0.87974106],
#        [ 0.36700952],
#        [-0.36423189],
#        [-1.24606136],
#        [-0.33998365],
#        [-1.09189238],
#        [ 0.28432837],
#        [-1.21933493],
#        [-0.15146399],
#        [-0.17182302],
#        [ 0.92354506],
#        [ 0.35503362],
#        [ 1.69379708],
#        [-0.25979254],
#        [-1.49178076],
#        [-0.63775672],
#        [ 0.04932799],
#        [ 0.34602205],
#        [-0.40604082],
#        [-0.7546344 ],
#        [-0.7328762 ],
#        [ 1.20624748],
#        [-0.30097304],
#        [ 0.43025651],
#        [ 0.461963  ],
#        [ 0.05011057],
#        [ 1.18371856],
#        [-0.98853205],
#        [-0.60807784],
#        [-0.85721215],
#        [ 0.36342862],
#        [ 0.42186152],
#        [-0.29537637],
#        [ 1.48242836],
#        [-1.16027359],
#        [-0.371536  ],
#        [-0.39283176],
#        [ 3.22402082],
#        [-0.66169667],
# ...

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
le.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
le.coef_
# Out:
# array([469.20755762])

# %%
le.intercept_
# Out:
# np.float64(5878.573404255313)

# %%
X_train_pred=le.predict(X_train_scaled)
X_train_pred
# Out:
# array([5655.53704816, 6777.59337107, 5465.79224924, 6050.77704564,
#        5707.67305054, 5293.9119982 , 5719.05050456, 5366.24924897,
#        6011.9824251 , 5306.45223849, 5807.50535639, 5797.95274503,
#        6311.90772607, 6045.15786121, 6673.31579504, 5756.67678213,
#        5178.61859829, 5579.33313106, 5901.71847051, 6040.92956473,
#        5688.05598457, 5524.49324132, 5534.70235238, 6444.55383788,
#        5737.35457842, 6080.45300954, 6095.32993576, 5902.08566464,
#        6433.98309669, 5414.74669399, 5593.25868803, 5476.36298314,
#        6049.0968594 , 6076.51401863, 5739.98057722, 6574.13999618,
#        5334.16426727, 5704.2459029 , 5694.25377285, 7391.30834067,
#        5568.10032618, 5266.12763755, 6148.12800912, 5613.9662157 ,
#        5850.9677921 , 7099.18313296, 5809.25787448])

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train, X_train_pred, color='r')
plt.xlabel("USD_INR")
plt.ylabel("Goldrate")
plt.show()

# %%
X_test_pred=le.predict(X_test_scaled)

# %%
X_test_pred
# Out:
# array([5702.05943009, 6127.70978702, 6494.65358787, 5645.83421639,
#        6155.1992781 , 5348.52935023])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(y_test,X_test_pred)
mae
# Out:
# 309.4602472570902

# %%
from sklearn.model_selection import RandomizedSearchCV
param_space = {'copy_X': [True,False], 
               'fit_intercept': [True,False], 
               'n_jobs': [1,5,10,15,None], 
               'positive': [True,False]}

# %%
search = RandomizedSearchCV(le, param_space, n_iter=50, cv=5)
search.fit(X_train_scaled, y_train)
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 40 is smaller than n_iter=50. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=LinearRegression(), n_iter=50,
#                    param_distributions={'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'n_jobs': [1, 5, 10, 15, None],
#                                         'positive': [True, False]})

# %%
search.best_params_
# Out:
# {'positive': True, 'n_jobs': 1, 'fit_intercept': True, 'copy_X': True}

# %%
tuned_model = LinearRegression(positive= True, n_jobs= 1, fit_intercept= True, copy_X= True)
tuned_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression(n_jobs=1, positive=True)

# %%
print("tuned ceof",tuned_model.coef_)
print("tuned intercept",tuned_model.intercept_)
# Out:
# tuned ceof [469.20755762]
# tuned intercept 5878.573404255313

# %%
import pickle

# %%
pickle.dump(le,open('le.pkl','wb'))

# %%
le_reloaded=pickle.load(open('le.pkl','rb'))

# %%
le_reloaded.coef_
# Out:
# array([469.20755762])

# %%
pickle.dump(sc,open('sc.pkl','wb'))
